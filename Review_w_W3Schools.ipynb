# %% [markdown]
# # Python Syntax

# %% [markdown]
# ## **Execute Python Syntax**
# - Python syntax can be executed by writing directly in the Command Line:

# %%
>>> print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# Or by creating a python file on the server, using the .py file extension, and running it in the Command Line:
# ```python
# C:\Users\YourName >python myfile.py
# ```

# %% [markdown]
# ## **Python Indentation**
# Indentation -> spaces at the beginning of a code line.
# Python uses indentation to indicate a block of code.
# Example

# %%
if 5 > 2:
  print("Five is greater than two!")
# Out:
# Five is greater than two!

# %% [markdown]
# Python will give us an error, specifically indentation error if we miss the indentation. Example:

# %%
if 5 > 2:
  print("Five is greater than two!")
# Out:
#   File "/tmp/ipykernel_3262/3793329317.py", line 2
#     print("Five is greater than two!")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %% [markdown]
# The number of spaces is up to us as a programmer, the most common use is four, but it has to be at least one. Some code editor already add tab as "four spaces" so we can just use that.
# Example:

# %%
if 5 > 2:
  print("Five is greater than two!");
if 5 > 2:
        print("Five is greater than two!")
# Out:
# Five is greater than two!
# Five is greater than two!

# %% [markdown]
# Both still work. We have to use the same number of spaces in the same block of code, otherwise Python will give us an error:

# %%
if 5 > 2:
  print("Five is greater than two");
    print("Five is greater than two");
# Out:
#   File "/tmp/ipykernel_3262/2747859960.py", line 3
#     print("Five is greater than two");
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ## **Python Variables**
# In python, a variable is created when you assign a value to it

# %%
x = 5
y = "Hello, World!"

# %% [markdown]
# ## Comments
# Python has commenting capability for the purpose of in-code documentation.
# Comment start with a #, and Python will render the rest of the line as a comment.
# Example:

# %%
print("Hello world!") #This is a comment
# Out:
# Hello world!

# %% [markdown]
# ## Statements
# A computer program is a list of **instructions** to be executed by a computer. In a programming language, these programming instructions are called statements.
# This is a statement

# %%
print("Python is fun!")
# Out:
# Python is fun!

# %% [markdown]
# In Python, a statement usually ends when the line ends. Most Python programs contain many statements and are executed one by one, in order.
# Semicolons are optional in Python.

# %% [markdown]
# ## Syntax Code Challenge

# %%
print("Hello World!")
print("Have a good day.")
print("Learning Python is fun!")
# Out:
# Hello World!
# Have a good day.
# Learning Python is fun!

# %% [markdown]
# # **Python Output / `print()`**
# You can use the `print()` to display text or output values.

# %%
print("Hello World!")

# %% [markdown]
# You can use the `print()` function as many times as you want. Each call prints text on a new line by default

# %%
print("Hello World!")
print("I am learning Python.")
print("It is nice")
# Out:
# Hello World!
# I am learning Python.
# It is nice

# %% [markdown]
# Text in Python must be inside quotes. You can use either `"` double quotes or `'` single quotes

# %%
print("This work")
print("This also work")
# Out:
# This work
# This also work

# %% [markdown]
# ## Print Without a New Line
# By default, the print() function ends with a new line. If you want to print multiple words on the same line, you can use the `end` parameter

# %%
print("Hello World!", end=" ")
print("This will print on the same line.")
# Out:
# Hello World! This will print on the same line.

# %% [markdown]
# ## Print Numbers
# We can also use the `print()` function to display numbers. However, unlike text we don't put numbers inside quotes:

# %%
print(3)
print(358)
print(50000)
# Out:
# 3
# 358
# 50000

# %% [markdown]
# It is also possible to do math inside print() function

# %%
print(3 + 3)
print(2 * 5)
# Out:
# 6
# 10

# %% [markdown]
# You can combine text and numbers in one output by separating them with a comma

# %%
print("I am", 35, "years old.")
# Out:
# I am 35 years old.

# %% [markdown]
# ## Output Challenge

# %%
print("I am", 25)
# Out:
# I am 25
