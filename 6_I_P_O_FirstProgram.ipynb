# %% [markdown]
# ## **I-P-O Programming**
# Input, Processing and Output are the essential thing that computers do.
# - Input: They gather some input maybe from a file or from a web service
# - Process: They do some work to the input
# - Output: They produce something
#
# ## **Converting User Input**
# - If we want to read a number from the user, we must convert it from a string to a number using a type conversion function.
# - Later we will deal with bad input data.

# %%
# convert elevator floors
inp = input("Europe floor?")
usf = int(inp) + 1
print("US floor", usf)
