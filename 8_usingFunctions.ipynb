# %% [markdown]
# DRY Principle -> Don't Repeat Yourself <br/>
# Function is basically a reusable code.
#
# ## Stored (and reused steps)
# ```python
# def thing():
#   print('Hello')
#   print('Fun')
# ```
# Example:

# %%
def thing(): # define the function
  print("Hello")
  print("Fun")
thing() # call the function
print("Zip")
thing()
# Out:
# Hello
# Fun
# Zip
# Hello
# Fun

# %%
big = max("Hello world")
print(big)
tiny = min("Hello world")
print(tiny)
# Out:
# w

# %% [markdown]
# ## Max Function
# A function is some stored code that we use. A function takes some input and produces an output.

# %%
def max(inp):
  ...
  ...
  for x in inp:

# %% [markdown]
# ## Type Conversions
# - When you put an integer and floating point in an expression, the integer is implicitly converted to a float
# You can control this with the built-in functions int() and float()

# %%
print(float(99) / 100)

i = 42
print(type(i))

f = float(i)
print(f)

print(type(f))

print(1 + 2 * float(3) / 4 - 5)
# Out:
# 0.99
# <class 'int'>
# 42.0
# <class 'float'>
# -2.5

# %% [markdown]
# Function will give you something back.

# %% [markdown]
# ## String Conversions
# - You can also use int() and float() to convert between strings and integers.
# - You will get an error if the string does not contain numeric characters.

# %%
sval = '123'
print(type(sval)) # it's a string
print(sval + 1)
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_156/3878450865.py in <cell line: 0>()
#       1 sval = '123'
#       2 print(type(sval)) # it's a string
# ----> 3 print(sval + 1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
ival = int(sval)
print(type(ival))
print(ival + 1)
# Out:
# <class 'int'>
# 124

# %%
nsv = 'hello bob'
niv = int(nsv)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_156/1078915547.py in <cell line: 0>()
#       1 nsv = 'hello bob'
# ----> 2 niv = int(nsv)
#
# ValueError: invalid literal for int() with base 10: 'hello bob'
